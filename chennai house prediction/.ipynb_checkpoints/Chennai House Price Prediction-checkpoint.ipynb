# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import shap
# from pandas_profiling import ProfileReport
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('train-chennai-sale.csv')

# %%
df.head()
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1  P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2  P01812       Adyar       909  04-02-2012             70        1.0
# 3  P05346   Velachery      1855  13-03-2010             14        3.0
# 4  P06210  Karapakkam      1226  05-10-2009             84        1.0
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  ... UTILITY_AVAIL  STREET MZZONE  \
# 0         1.0       3  AbNormal        Yes  ...        AllPub   Paved      A
# 1         1.0       5  AbNormal         No  ...        AllPub  Gravel     RH
# 2         1.0       3  AbNormal        Yes  ...           ELO  Gravel     RL
# 3         2.0       5    Family         No  ...       NoSewr    Paved      I
# 4         1.0       3  AbNormal        Yes  ...        AllPub  Gravel      C
#
#   QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  SALES_PRICE
# 0      4.0         3.9         4.9       4.330   380000  144400      7600000
# 1      4.9         4.2         2.5       3.765   760122  304049     21717770
# 2      4.1         3.8         2.2       3.090   421094   92114     13159200
# 3      4.7         3.9         3.6       4.010   356321   77042      9630290
# 4      3.0         2.5         4.1       3.290   237000   74063      7406250
#
# [5 rows x 22 columns]

# %% [markdown]
# ## UNDERSTANDING THE DATA
#  <a id =0> </a>

# %% [markdown]
# <html>
# <style>
# html{font-family:Monaco;}
#
# </style>
# <h3 style = "font-family:Arial" >IN SALE_COND COLUMN:</h3>
#     <strong>FAMILY</strong>: SELLLING HOUSE TO YOUR OWN FAMILY/KIN<br>
#     <strong>PARTIAL</strong>: ONLY SELLING A PART OF THE HOUSE<br>
#     <strong>ADJLAND</strong>: SELLING A NEABY LAND<br>
#     <strong>NORMAL SALE</strong>: NORMAL SALE<br>
#     <strong>ABNORMAL</strong>: IF ITS NONE OF THE ABOVE CONDITION<br>
# </html>

# %% [markdown]
# <html>
# <style>
# h3{font-family:"Arial";}
# </style>
# <h3 >IN BUILD TYPE COLUMN:</h3>
#     <strong>House</strong>: Normal House<br>
#     <strong>Commercial</strong>: For Commercial Purposes<br>
#     <strong>Others</strong>: Houses for other purposes<br>
# </html>

# %% [markdown]
# <html>
# <style>
# h3{font-family:"Helvetica";}
# </style>
# <h3 >IN MZZONE COLUMN:</h3>
# <strong>A</strong>: Agricultural<br>
# <strong>I</strong>: Industrial<br>
# <strong>C</strong>: Commercial<br>
# <strong>RL</strong>: Residential Low Density<br>
# <strong>RM</strong>: Residential Medium Density<br>
# <strong>RH</strong>: Residential High Density
# </html>

# %% [markdown]
# <html>
# <style>
# h3{font-family:"Arial";}
# </style>
# <h4 >IN PARK_FACIL COLUMN:</h4>Whether Parking Facility is available or not? (Yes/No)
# <h4 >IN UTILITY_AVAIL COLUMN:</h4>What all facilites are availabe in the house...
# <h4 >IN STREET COLUMN:</h4>Whether the road connected to the house is Paved, Gravel or has NO Acess
# </html>

# %% [markdown]
# <span style = "font:Monaco">BEFORE I SELL THE HOUSE WOULD I KNOW THE REG_FEE AND COMMIS FEE?</span> <br>
# <span style =" font-size: 16px">`OBVIOUSLY NO( These columns to be dropped )`</span>

# %% [markdown]
# ## DATA CLEANING/TRANSFORMATION
#
# > 1. <SPAN style = "color:GREEN;font-size:15.5px">[CONVERTING COL HEADERS INTO `LOWER CASE`](#1)<SPAN><br>
# > 2. <SPAN style = "color:GREEN;font-size:15.5px">[CLEANING AND TRANFORMING](#2)<SPAN><br>
#     >> a. [CORRECTING SPELLING MISTAKES OF CATEGORICAL COLS](#2.1)<br>
#     >> b. [FILLING NaN VALUES OF NUMERICAL COLS](#2.2)<br>
#     >> c. [DROPPING THE DUPLICATE ROWS](#2.3)<br>
#     >> d. [CHANGING THE TYPES](#2.4) <br>
# > 3. <SPAN style = "color:GREEN;font-size:15.5px">[FINDING (Derived Feature) `house_age = date_sale - date_build`](#3)<SPAN><br>
# > 4. <SPAN style = "color:GREEN;font-size:15.5px">[DROPPING `Prt_id(unique), Date_sale, Date_Built, Reg_fee & Commis`<SPAN> COLUMNS](#4)<br>

# %% [markdown]
# ## EDA
# > 1. <SPAN style = "color:GREEN;font-size:15.5px">[UNIVARIATE ANALYSIS](#21)<SPAN><BR>
# > 2. <SPAN style = "color:GREEN;font-size:15.5px">[BIVARIATE ANALYSIS](#22)<SPAN>

# %% [markdown]
# ## ENCODING
# > 1. <SPAN style = "color:GREEN;font-size:15.5px">[ONE HOT ENCODING](#31)<SPAN><BR>
# > 2. <SPAN style = "color:GREEN;font-size:15.5px">[LABEL ENCODING](#32)<SPAN>

# %% [markdown]
# ## SPLITTING
# [click here](#4)

# %% [markdown]
# ## SCALING
# > 1. <SPAN style = "color:GREEN;font-size:15.5px">[STANDARD SCALER](#5)<SPAN><BR>

# %% [markdown]
# ## MODELLING
# > 1. [LINEAR REGRESSION](#6.1)<BR>
# > 2. [KNN](#6.2)<BR>
# > 3. [DECISION TREE](#6.3)<BR>
# > 4. [RANDOM FOREST](#6.4)<BR>
# > 5. [XGBOOST](#6.5)<BR>

# %% [markdown]
# ## FEATURE IMPORTANCES
# [click here](#7)

# %% [markdown]
# ## CONCLUSION
# [click here](#8)

# %% [markdown]
# ## DATA CLEANING/TRANSFORMATION

# %% [markdown]
#  <a id =1> </a>
# <b style = "font-size:15.5px">STEP 1:</b> <i style = "color:blue;font-size:15.5px"> CONVERTING COL HEADERS INTO `LOWER CASE`<i><br>

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['prt_id', 'area', 'int_sqft', 'date_sale', 'dist_mainroad', 'n_bedroom',
#        'n_bathroom', 'n_room', 'sale_cond', 'park_facil', 'date_build',
#        'buildtype', 'utility_avail', 'street', 'mzzone', 'qs_rooms',
#        'qs_bathroom', 'qs_bedroom', 'qs_overall', 'reg_fee', 'commis',
#        'sales_price'],
#       dtype='object')

# %% [markdown]
#  <a id =2> </a>
# <b style = "font-size:16.5px">STEP 2:</b><i style = "color:blue;font-size:16.5px">  CLEANING AND TRANSFORMING COLS</i>

# %% [markdown]
#  <a id =2.1> </a>
#  <b style = "font-size:15.5px">STEP 2a:</b><i style = "color:blue;font-size:15.5px">  CHECK FOR SPELLING MISTAKES IN THE CATEGORICAL COLS</i>

# %%
col_list =['area','sale_cond','park_facil','buildtype','utility_avail','street']
print("Printing unique value of the categorical columns: \n")
for i in col_list:
    print("{} column: {}\t\n".format(i,df[i].unique()))
# Out:
# Printing unique value of the categorical columns:
#
# area column: ['Karapakkam' 'Anna Nagar' 'Adyar' 'Velachery' 'Chrompet' 'KK Nagar'
#  'TNagar' 'T Nagar' 'Chrompt' 'Chrmpet' 'Karapakam' 'Ana Nagar' 'Chormpet'
#  'Adyr' 'Velchery' 'Ann Nagar' 'KKNagar']
#
# sale_cond column: ['AbNormal' 'Family' 'Partial' 'AdjLand' 'Normal Sale' 'Ab Normal'
#  'Partiall' 'Adj Land' 'PartiaLl']
#
# park_facil column: ['Yes' 'No' 'Noo']
#
# buildtype column: ['Commercial' 'Others' 'Other' 'House' 'Comercial']
#
# utility_avail column: ['AllPub' 'ELO' 'NoSewr ' 'NoSeWa' 'All Pub']
#
# street column: ['Paved' 'Gravel' 'No Access' 'Pavd' 'NoAccess']

# %%
#Correcting the spelling mistakes of the above columns
df['area'] = df.area.replace({'Karapakam':'Karapakkam','Anna Nagar':'AnnaNagar','Ana Nagar':'AnnaNagar','Ann Nagar':'AnnaNagar',\
                              'KK Nagar':'KKNagar','T Nagar':'TNagar',\
                              'Chrompt':'Chrompet','Chrmpet':'Chrompet','Chormpet':'Chrompet',\
                              'Velchery':'Velachery','Adyr':'Adyar'
                             })
df['sale_cond'] = df.sale_cond.replace({'Ab Normal':'AbNormal','Partiall':'Partial','PartiaLl':'Partial','Adj Land':'AdjLand','Normal Sale':'NormalSale'})
df['park_facil'] = df.park_facil.replace({'Noo':'No'})
df['buildtype'] = df.buildtype.replace({'Other':'Others','Comercial':'Commercial'})
df['utility_avail'] = df.utility_avail.replace({'All Pub':'AllPub','NoSeWa':'NoSewr','NoSewr ':'NoSewr'})
df['street'] = df.street.replace({'No Access':'NoAccess','Pavd':'Paved'})

# %%
col_list =['area','sale_cond','park_facil','buildtype','utility_avail','street']
print("Printing unique value of the categorical columns: \n")
for i in col_list:
    print("{} column: {}\t\n".format(i,df[i].unique()))
# Out:
# Printing unique value of the categorical columns:
#
# area column: ['Karapakkam' 'AnnaNagar' 'Adyar' 'Velachery' 'Chrompet' 'KKNagar'
#  'TNagar']
#
# sale_cond column: ['AbNormal' 'Family' 'Partial' 'AdjLand' 'NormalSale']
#
# park_facil column: ['Yes' 'No']
#
# buildtype column: ['Commercial' 'Others' 'House']
#
# utility_avail column: ['AllPub' 'ELO' 'NoSewr']
#
# street column: ['Paved' 'Gravel' 'NoAccess']

# %% [markdown]
#  <a id =2.2> </a>
# <b style = "font-size:16px">STEP 2b:</b><p style = "color:blue;"><strong style = "font-size:15.5px">FILLING NULL VALUES</strong><br><SPAN style = "font-size:14px"><i>1. Filling NULL values with mean for the numerical columns</i><br><i>2. Filling NULL values with mode for discrete numerical columns</i></SPAN></p>

# %%
df.isna().sum()
# Out:
# prt_id            0
# area              0
# int_sqft          0
# date_sale         0
# dist_mainroad     0
# n_bedroom         1
# n_bathroom        5
# n_room            0
# sale_cond         0
# park_facil        0
# date_build        0
# buildtype         0
# utility_avail     0
# street            0
# mzzone            0
# qs_rooms          0
# qs_bathroom       0
# qs_bedroom        0
# qs_overall       48
# reg_fee           0
# commis            0
# sales_price       0
# dtype: int64

# %%
df['n_bedroom'] =df['n_bedroom'].fillna(1)
df['n_bathroom'] =df['n_bathroom'].fillna(1)
df['qs_overall'] =df['qs_overall'].fillna(df['qs_overall'].mean())

# %%
df.isnull().sum()
# Out:
# prt_id           0
# area             0
# int_sqft         0
# date_sale        0
# dist_mainroad    0
# n_bedroom        0
# n_bathroom       0
# n_room           0
# sale_cond        0
# park_facil       0
# date_build       0
# buildtype        0
# utility_avail    0
# street           0
# mzzone           0
# qs_rooms         0
# qs_bathroom      0
# qs_bedroom       0
# qs_overall       0
# reg_fee          0
# commis           0
# sales_price      0
# dtype: int64

# %% [markdown]
#  <a id =2.3> </a>
# <b style = "font-size:15.5px">STEP 2c:</b><i style = "font-family:Helvetica;color:blue;font-size:15.5px"> CHECKING FOR DUPLICATE ROWS AND DROPPING THEM</i>

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (7109, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7109 entries, 0 to 7108
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   prt_id         7109 non-null   object
#  1   area           7109 non-null   object
#  2   int_sqft       7109 non-null   int64
#  3   date_sale      7109 non-null   object
#  4   dist_mainroad  7109 non-null   int64
#  5   n_bedroom      7109 non-null   float64
#  6   n_bathroom     7109 non-null   float64
#  7   n_room         7109 non-null   int64
#  8   sale_cond      7109 non-null   object
#  9   park_facil     7109 non-null   object
#  10  date_build     7109 non-null   object
#  11  buildtype      7109 non-null   object
#  12  utility_avail  7109 non-null   object
#  13  street         7109 non-null   object
#  14  mzzone         7109 non-null   object
#  15  qs_rooms       7109 non-null   float64
#  16  qs_bathroom    7109 non-null   float64
#  17  qs_bedroom     7109 non-null   float64
#  18  qs_overall     7109 non-null   float64
#  19  reg_fee        7109 non-null   int64
#  20  commis         7109 non-null   int64
#  21  sales_price    7109 non-null   int64
# dtypes: float64(6), int64(6), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
#  <a id =2.4> </a>
# <b style = "font-size:15.5px">STEP 2d:</b><i style = "color:blue;font-size:15.5px">CONVERTING n_bathroom AND n_bedroom INTO INT DATATYPE</i>

# %%
df.n_bathroom = df.n_bathroom.astype('int64')
df.n_bedroom = df.n_bedroom.astype('int64')

# %% [markdown]
#  <a id =3> </a>
# <b style = "font-size:15.5px">STEP 3:</b><i style = "color:blue;font-size:15.5px"> FINDING DERIVED FEATURE `house_age`</i>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7109 entries, 0 to 7108
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   prt_id         7109 non-null   object
#  1   area           7109 non-null   object
#  2   int_sqft       7109 non-null   int64
#  3   date_sale      7109 non-null   object
#  4   dist_mainroad  7109 non-null   int64
#  5   n_bedroom      7109 non-null   int64
#  6   n_bathroom     7109 non-null   int64
#  7   n_room         7109 non-null   int64
#  8   sale_cond      7109 non-null   object
#  9   park_facil     7109 non-null   object
#  10  date_build     7109 non-null   object
#  11  buildtype      7109 non-null   object
#  12  utility_avail  7109 non-null   object
#  13  street         7109 non-null   object
#  14  mzzone         7109 non-null   object
#  15  qs_rooms       7109 non-null   float64
#  16  qs_bathroom    7109 non-null   float64
#  17  qs_bedroom     7109 non-null   float64
#  18  qs_overall     7109 non-null   float64
#  19  reg_fee        7109 non-null   int64
#  20  commis         7109 non-null   int64
#  21  sales_price    7109 non-null   int64
# dtypes: float64(4), int64(8), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# <i style = "color:blue;font-size:14px">CONVERTING THE DATE COLUMNS INTO DATE TIME</i>

# %%
df['date_sale'] =pd.to_datetime(df['date_sale'])
df['date_build'] =pd.to_datetime(df['date_build']);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7109 entries, 0 to 7108
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   prt_id         7109 non-null   object
#  1   area           7109 non-null   object
#  2   int_sqft       7109 non-null   int64
#  3   date_sale      7109 non-null   datetime64[ns]
#  4   dist_mainroad  7109 non-null   int64
#  5   n_bedroom      7109 non-null   int64
#  6   n_bathroom     7109 non-null   int64
#  7   n_room         7109 non-null   int64
#  8   sale_cond      7109 non-null   object
#  9   park_facil     7109 non-null   object
#  10  date_build     7109 non-null   datetime64[ns]
#  11  buildtype      7109 non-null   object
#  12  utility_avail  7109 non-null   object
#  13  street         7109 non-null   object
#  14  mzzone         7109 non-null   object
#  15  qs_rooms       7109 non-null   float64
#  16  qs_bathroom    7109 non-null   float64
#  17  qs_bedroom     7109 non-null   float64
#  18  qs_overall     7109 non-null   float64
#  19  reg_fee        7109 non-null   int64
#  20  commis         7109 non-null   int64
#  21  sales_price    7109 non-null   int64
# dtypes: datetime64[ns](2), float64(4), int64(8), object(8)
# memory usage: 1.2+ MB

# %%
df['house_age']= np.round((df.date_sale - df.date_build).dt.days/365.25,2)

# %%
df['house_age']
# Out:
# 0       43.89
# 1       10.99
# 2       19.58
# 3       21.98
# 4       29.57
#         ...
# 7104    49.12
# 7105     8.75
# 7106    28.62
# 7107    31.33
# 7108    43.97
# Name: house_age, Length: 7109, dtype: float64

# %% [markdown]
# <b style = "font-size:15.5px">STEP 4:</b><i style = "color:blue;font-size:15.5px"> REMOVING THE EXTRA COLS</i>

# %%
df.columns
# Out:
# Index(['prt_id', 'area', 'int_sqft', 'date_sale', 'dist_mainroad', 'n_bedroom',
#        'n_bathroom', 'n_room', 'sale_cond', 'park_facil', 'date_build',
#        'buildtype', 'utility_avail', 'street', 'mzzone', 'qs_rooms',
#        'qs_bathroom', 'qs_bedroom', 'qs_overall', 'reg_fee', 'commis',
#        'sales_price', 'house_age'],
#       dtype='object')

# %%
df.drop(['prt_id','date_sale','date_build','reg_fee', 'commis'],axis = 1,inplace = True)

# %%
df.head()
# Out:
#          area  int_sqft  dist_mainroad  n_bedroom  n_bathroom  n_room  \
# 0  Karapakkam      1004            131          1           1       3
# 1   AnnaNagar      1986             26          2           1       5
# 2       Adyar       909             70          1           1       3
# 3   Velachery      1855             14          3           2       5
# 4  Karapakkam      1226             84          1           1       3
#
#   sale_cond park_facil   buildtype utility_avail  street mzzone  qs_rooms  \
# 0  AbNormal        Yes  Commercial        AllPub   Paved      A       4.0
# 1  AbNormal         No  Commercial        AllPub  Gravel     RH       4.9
# 2  AbNormal        Yes  Commercial           ELO  Gravel     RL       4.1
# 3    Family         No      Others        NoSewr   Paved      I       4.7
# 4  AbNormal        Yes      Others        AllPub  Gravel      C       3.0
#
#    qs_bathroom  qs_bedroom  qs_overall  sales_price  house_age
# 0          3.9         4.9       4.330      7600000      43.89
# 1          4.2         2.5       3.765     21717770      10.99
# 2          3.8         2.2       3.090     13159200      19.58
# 3          3.9         3.6       4.010      9630290      21.98
# 4          2.5         4.1       3.290      7406250      29.57

# %% [markdown]
# <i style = "color:blue;font-size:14px"> REORDERING THE INDEXES</i>

# %%
col_list = []
col_list = list(df.columns[:-2])+list(df.columns[-1:-3:-1])
df = df.reindex(columns = col_list)

# %%
df.head()
# Out:
#          area  int_sqft  dist_mainroad  n_bedroom  n_bathroom  n_room  \
# 0  Karapakkam      1004            131          1           1       3
# 1   AnnaNagar      1986             26          2           1       5
# 2       Adyar       909             70          1           1       3
# 3   Velachery      1855             14          3           2       5
# 4  Karapakkam      1226             84          1           1       3
#
#   sale_cond park_facil   buildtype utility_avail  street mzzone  qs_rooms  \
# 0  AbNormal        Yes  Commercial        AllPub   Paved      A       4.0
# 1  AbNormal         No  Commercial        AllPub  Gravel     RH       4.9
# 2  AbNormal        Yes  Commercial           ELO  Gravel     RL       4.1
# 3    Family         No      Others        NoSewr   Paved      I       4.7
# 4  AbNormal        Yes      Others        AllPub  Gravel      C       3.0
#
#    qs_bathroom  qs_bedroom  qs_overall  house_age  sales_price
# 0          3.9         4.9       4.330      43.89      7600000
# 1          4.2         2.5       3.765      10.99     21717770
# 2          3.8         2.2       3.090      19.58     13159200
# 3          3.9         3.6       4.010      21.98      9630290
# 4          2.5         4.1       3.290      29.57      7406250

# %%
df= df.rename(columns = {'house_age':'house_age(in years)'})

# %%
df.isna().sum()
# Out:
# area                   0
# int_sqft               0
# dist_mainroad          0
# n_bedroom              0
# n_bathroom             0
# n_room                 0
# sale_cond              0
# park_facil             0
# buildtype              0
# utility_avail          0
# street                 0
# mzzone                 0
# qs_rooms               0
# qs_bathroom            0
# qs_bedroom             0
# qs_overall             0
# house_age(in years)    0
# sales_price            0
# dtype: int64

# %% [markdown]
# ## EDA

# %% [markdown]
#  <a id =21> </a>
# <b style = "font-size:15.5px">STEP 1:</b><i style = "color:blue;font-size:15.5px"> UNIVARIATE ANALYSIS</i>

# %%
cat_columns =['area','n_bedroom','n_bathroom','n_room','sale_cond','park_facil','buildtype','utility_avail','street','mzzone']
numerical_columns = ['int_sqft','dist_mainroad','qs_rooms','qs_bathroom','qs_bedroom','qs_overall','house_age(in years)']

# %% [markdown]
# <i style = "color:blue;font-size:14px"> CATEGORICAL COLS UNIVARIATE ANALYSIS</i>

# %%
figure,axes = plt.subplots(len(cat_columns),1,figsize=(8,8*len(cat_columns)))
for index,i in enumerate(cat_columns):
    sns.countplot(ax=axes[index],x= i,data =df,order = df[i].value_counts().index[::-1])

# %% [markdown]
# <span style = "color: red"><b>Inferences from the above plot:</b></span>
# <span style = "color: gray"><br>
# 1. Chrompet has most number of house while TNagar has the least.<br>
# 2. Houses with 1 bedroom is most preferred following by 2 bedrooms.<br>
# 3. Houses with 3 to 4 rooms is most preffered.<br>
# 4. Almost half of the houses doesn't have parking facility.<br>
# 5. 52% of houses does have no Sewer facility.<br>
# 6. 28% of houses doesn't have proper road access.<br>
# 7. Houses for Industrial,Agricultural and Commercial Purposes are very less.</span>

# %% [markdown]
# <i style = "color:blue;font-size:14px"> NUMERICAL COLS UNIVARIATE ANALYSIS</i>

# %%
figure,axes = plt.subplots(len(numerical_columns),2,figsize=(15,8*len(numerical_columns)))
for index,i in enumerate(numerical_columns):
    sns.histplot(ax = axes[index][0],x=df[i],kde = True)
    sns.boxplot(ax = axes[index][1],x=df[i],orient = 'h')

# %% [markdown]
# Although qs_overall has an outlier but we cannot remove it, removing it may lead to pattern loss.

# %% [markdown]
#  <a id =22> </a>
# <b style = "font-size:15.5px">STEP 2:</b><i style = "color:blue;font-size:15.5px"> BIVARIATE ANALYSIS</i>

# %%
numerical_columns = ['int_sqft','dist_mainroad','qs_overall']
new_cols = ['qs_rooms','qs_bathroom','qs_bedroom','grp_house_age']
cat_columns =['area','n_bedroom','n_bathroom','n_room','sale_cond','park_facil','buildtype','utility_avail','street','mzzone']

# %% [markdown]
# <i style = "color:blue;font-size:14px"> CATEGORICAL COLS BIVARIATE ANALYSIS</i>

# %%
figure,axes = plt.subplots(len(cat_columns),1,figsize=(8,8*len(cat_columns)))
for index,i in enumerate(cat_columns):
    sns.barplot(ax=axes[index],x= i,y='sales_price',data =df,order = df.groupby(i)['sales_price'].mean().reset_index().sort_values('sales_price')[i])

# %% [markdown]
# No change needed: `n_bedroom`<BR>
# Label Encoding: `area,park_facil,utility_avail,street,mzzone(0,1,2,4,5,6),n_bathroom,n_room(0,1,2,3,3)`<BR>
# One Hot Encoding: `buildtyp`e<BR>
# Drop: `sale_cond(it shows uniform relationship no relationship with target variable)`<BR>

# %% [markdown]
# <i style = "color:blue;font-size:14px"> NUMERICAL COLS BIVARIATE ANALYSIS</i>

# %%
figure,axes = plt.subplots(len(numerical_columns),1,figsize=(15,8*len(numerical_columns)))
for index,i in enumerate(numerical_columns):
    sns.scatterplot(ax = axes[index],x=df[i],y=df['sales_price'])

# %% [markdown]
# <i style = "color:blue;font-size:15.5px"> BINNING HOUSE AGE, QS_ROOMS, QS_BATHROOM AND QS_BEDROOM FOR BETTER VISUALIZATION<br></i>

# %%
#it bins the house age into 10 bins
df['grp_house_age'] = pd.cut(df['house_age(in years)'],10)

# %%
new_cols = ['qs_rooms','qs_bathroom','qs_bedroom','grp_house_age']
figure,axes = plt.subplots(len(new_cols),1,figsize=(15,8*len(new_cols)))
for index,i in enumerate(new_cols):
    df.groupby(i)['sales_price'].mean().plot(kind = 'bar',ax = axes[index])

# %% [markdown]
# Drop: qs_rooms,qs_bathroom,qs_bedroom,dist_mainroad

# %% [markdown]
# ## ENCODING

# %% [markdown]
# <i style = "color:blue;font-size:14px"> MAKING A BACKUP COPY</i>

# %%
data = df.copy(deep = False)

# %%
df1 = data.copy(deep = False)

# %%
df.head()
# Out:
#          area  int_sqft  dist_mainroad  n_bedroom  n_bathroom  n_room  \
# 0  Karapakkam      1004            131          1           1       3
# 1   AnnaNagar      1986             26          2           1       5
# 2       Adyar       909             70          1           1       3
# 3   Velachery      1855             14          3           2       5
# 4  Karapakkam      1226             84          1           1       3
#
#   sale_cond park_facil   buildtype utility_avail  street mzzone  qs_rooms  \
# 0  AbNormal        Yes  Commercial        AllPub   Paved      A       4.0
# 1  AbNormal         No  Commercial        AllPub  Gravel     RH       4.9
# 2  AbNormal        Yes  Commercial           ELO  Gravel     RL       4.1
# 3    Family         No      Others        NoSewr   Paved      I       4.7
# 4  AbNormal        Yes      Others        AllPub  Gravel      C       3.0
#
#    qs_bathroom  qs_bedroom  qs_overall  house_age(in years)  sales_price  \
# 0          3.9         4.9       4.330                43.89      7600000
# 1          4.2         2.5       3.765                10.99     21717770
# 2          3.8         2.2       3.090                19.58     13159200
# 3          3.9         3.6       4.010                21.98      9630290
# 4          2.5         4.1       3.290                29.57      7406250
#
#       grp_house_age
# 0  (40.208, 45.392]
# 1   (9.104, 14.288]
# 2  (19.472, 24.656]
# 3  (19.472, 24.656]
# 4   (24.656, 29.84]

# %% [markdown]
#  <a id =31> </a>
# <b style = "font-size:15.5px">STEP 1:</b><i style = "color:blue;font-size:15.5px"> ONE HOT ENCODING</i>

# %%
#one hot encoding for build type column
from sklearn.preprocessing import OneHotEncoder
oh = OneHotEncoder(drop = 'first')

# %%
build = pd.DataFrame(oh.fit_transform(df[['buildtype']]).toarray())

# %%
df['buildtype0'] = build.iloc[:,0]
df['buildtype1'] = build.iloc[:,1]

# %%
df.head()
# Out:
#          area  int_sqft  dist_mainroad  n_bedroom  n_bathroom  n_room  \
# 0  Karapakkam      1004            131          1           1       3
# 1   AnnaNagar      1986             26          2           1       5
# 2       Adyar       909             70          1           1       3
# 3   Velachery      1855             14          3           2       5
# 4  Karapakkam      1226             84          1           1       3
#
#   sale_cond park_facil   buildtype utility_avail  ... mzzone qs_rooms  \
# 0  AbNormal        Yes  Commercial        AllPub  ...      A      4.0
# 1  AbNormal         No  Commercial        AllPub  ...     RH      4.9
# 2  AbNormal        Yes  Commercial           ELO  ...     RL      4.1
# 3    Family         No      Others        NoSewr  ...      I      4.7
# 4  AbNormal        Yes      Others        AllPub  ...      C      3.0
#
#    qs_bathroom  qs_bedroom  qs_overall  house_age(in years)  sales_price  \
# 0          3.9         4.9       4.330                43.89      7600000
# 1          4.2         2.5       3.765                10.99     21717770
# 2          3.8         2.2       3.090                19.58     13159200
# 3          3.9         3.6       4.010                21.98      9630290
# 4          2.5         4.1       3.290                29.57      7406250
#
#       grp_house_age buildtype0  buildtype1
# 0  (40.208, 45.392]        0.0         0.0
# 1   (9.104, 14.288]        0.0         0.0
# 2  (19.472, 24.656]        0.0         0.0
# 3  (19.472, 24.656]        0.0         1.0
# 4   (24.656, 29.84]        0.0         1.0
#
# [5 rows x 21 columns]

# %%
df['area'].unique()
# Out:
# array(['Karapakkam', 'AnnaNagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KKNagar', 'TNagar'], dtype=object)

# %% [markdown]
#  <a id =32> </a>
# <b style = "font-size:15.5px">STEP 2:</b><i style = "color:blue;font-size:15.5px"> LABEL ENCODING</i>

# %%
#label encoding 
df.area = df.area.map({'Karapakkam':0,'Adyar':1,'Chrompet':2,'Velachery':3,\
'KKNagar':4,'AnnaNagar':5,'TNagar':6
})
df.park_facil = df.park_facil.map({'Yes':1,'No':0})
df.utility_avail = df.utility_avail.map({'ELO':0,'NoSewr':1,"AllPub":2})
df.street = df.street.map({'NoAccess':0,'Paved':1,'Gravel':2})
df.mzzone = df.mzzone.map({'A':0,'C':1,'I':2,'RH':4,'RL':5,'RM':6})
df.n_room = df.n_room.map({2:0,3:1,4:2,5:3,6:3})

# %%
# delete qs_bedroom,bathroom,room,distfrommainroad
df.drop(['sale_cond','buildtype','dist_mainroad','qs_rooms','qs_bathroom','qs_bedroom'],axis =1 ,inplace = True)
df.head()
# Out:
#    area  int_sqft  n_bedroom  n_bathroom  n_room  park_facil  utility_avail  \
# 0     0      1004          1           1       1           1              2
# 1     5      1986          2           1       3           0              2
# 2     1       909          1           1       1           1              0
# 3     3      1855          3           2       3           0              1
# 4     0      1226          1           1       1           1              2
#
#    street  mzzone  qs_overall  house_age(in years)  sales_price  \
# 0       1       0       4.330                43.89      7600000
# 1       2       4       3.765                10.99     21717770
# 2       2       5       3.090                19.58     13159200
# 3       1       2       4.010                21.98      9630290
# 4       2       1       3.290                29.57      7406250
#
#       grp_house_age  buildtype0  buildtype1
# 0  (40.208, 45.392]         0.0         0.0
# 1   (9.104, 14.288]         0.0         0.0
# 2  (19.472, 24.656]         0.0         0.0
# 3  (19.472, 24.656]         0.0         1.0
# 4   (24.656, 29.84]         0.0         1.0

# %% [markdown]
#  <a id =4> </a>
# ## SPLITTING

# %%
y = df['sales_price']
x = df.drop(['sales_price','grp_house_age'],axis =1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 20)

# %% [markdown]
#  <a id =5> </a>
# ## SCALING

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train= pd.DataFrame(sc.fit_transform(x_train),columns = x_train.columns)

# %%
x_train
# Out:
#           area  int_sqft  n_bedroom  n_bathroom    n_room  park_facil  \
# 0    -0.844066 -0.513836  -0.791773   -0.516597 -0.691736    0.995321
# 1    -0.844066 -0.605813  -0.791773   -0.516597 -0.691736    0.995321
# 2     1.308650  0.933694   0.456288   -0.516597  1.407691   -1.004701
# 3     1.308650  0.668715  -0.791773   -0.516597  0.357978   -1.004701
# 4     1.846829  1.244661   0.456288   -0.516597  1.407691    0.995321
# ...        ...       ...        ...         ...       ...         ...
# 5326  0.232292  0.815439   0.456288   -0.516597  0.357978    0.995321
# 5327 -0.305887 -0.408721  -0.791773   -0.516597 -0.691736    0.995321
# 5328  1.846829  0.686234  -0.791773   -0.516597  0.357978   -1.004701
# 5329  1.846829  0.931504   0.456288   -0.516597  1.407691    0.995321
# 5330  0.770471 -0.189730  -0.791773   -0.516597 -0.691736    0.995321
#
#       utility_avail    street    mzzone  qs_overall  house_age(in years)  \
# 0          1.384644 -0.088278  0.484531    0.219354             1.190713
# 1         -0.063284  1.173413 -2.207250    0.047875            -0.024621
# 2         -0.063284 -0.088278 -0.053826    0.810004             1.278275
# 3         -1.511212 -0.088278 -0.053826   -0.256976            -0.607560
# 4          1.384644 -1.349970  1.022887    1.067222            -0.834574
# ...             ...       ...       ...         ...                  ...
# 5326      -0.063284  1.173413  1.022887    1.476866             0.380760
# 5327      -0.063284 -1.349970  1.022887   -1.133424            -0.834574
# 5328      -1.511212 -0.088278  1.022887   -1.162004            -1.576422
# 5329      -0.063284 -1.349970  1.022887   -1.476382            -1.239955
# 5330      -0.063284 -0.088278  1.022887    0.676631            -0.753498
#
#       buildtype0  buildtype1
# 0       1.368888   -0.707107
# 1      -0.730520    1.414214
# 2      -0.730520    1.414214
# 3      -0.730520   -0.707107
# 4       1.368888   -0.707107
# ...          ...         ...
# 5326    1.368888   -0.707107
# 5327   -0.730520    1.414214
# 5328   -0.730520   -0.707107
# 5329   -0.730520    1.414214
# 5330   -0.730520   -0.707107
#
# [5331 rows x 13 columns]

# %% [markdown]
#  <a id =6> </a>
# ## MODELLING

# %%
from xgboost import plot_importance,XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor

# %%
from sklearn.metrics import r2_score as r2
from sklearn.model_selection import cross_val_score as cvs

# %%
# lr = LinearRegression()
# kn = KNeighborsRegressor() # check with weighted distnace and no of estimators
# dt = DecisionTreeRegressor() #change the max depth
# rf = RandomForestRegressor()
# ab = AdaBoostRegressor()
# gr = GradientBoostingRegressor()
# xg = xg()

# %% [markdown]
# #### LINEAR REGRESSION
# <a id =6.1> </a>

# %%
score = {}

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
print("Linear Regressor Training score: ",lr.score(x_train,y_train))
print("Linear Regressor Cross Validation score: ",cvs(lr,x_train,y_train,cv=10,scoring = 'r2').mean()) ;
# Out:
# Linear Regressor Training score:  0.9129347733399702
# Linear Regressor Cross Validation score:  0.9120807004250727

# %%
score['Linear Regression'] = cvs(lr,x_train,y_train,cv=10,scoring = 'r2').mean()

# %%
score
# Out:
# {'Linear Regression': 0.9120807004250727}

# %%
lr.intercept_
# Out:
# 10901346.838304259

# %%
#after scaling check the data

# %%
coef = pd.Series({i:abs(j) for i,j in zip(x_train.columns,lr.coef_)})
coef.sort_values(ascending = False).plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
'''
here there are separate feature imoportances values for buildtype0 and buildype1, 
what if we want the feature importances of the column buildtype?
''';

# %% [markdown]
# #### KNN
# <a id =6.2> </a>

# %%
#KNN
dict = {}
for i in range(5,150):
    kn = KNeighborsRegressor(n_neighbors=i)
    dict[i] = cvs(kn,x_train,y_train,cv = 10,scoring = 'r2').mean()
    kn.fit(x_train,y_train)
    print("Cross Validation Score for {}th neighbour:".format(i),cvs(kn,x_train,y_train,cv = 10,scoring = 'r2').mean())

li = []
for i,j in dict.items():
    if len(li) == 0:
        li.extend([i,j])
    elif dict[i] > li[1]:
        li[0] = i
        li[1] = dict[i]
print("\nThe best score for KNN is {} for n neighbours:{}".format(li[1],li[0]))
# Out:
# Cross Validation Score for 5th neighbour: 0.9433452550196405
# Cross Validation Score for 6th neighbour: 0.9429536648151087
# Cross Validation Score for 7th neighbour: 0.9416094198839577
# Cross Validation Score for 8th neighbour: 0.9410856194476628
# Cross Validation Score for 9th neighbour: 0.940011492440607
# Cross Validation Score for 10th neighbour: 0.9382598160011316
# Cross Validation Score for 11th neighbour: 0.9373578870963006
# Cross Validation Score for 12th neighbour: 0.9360116631965797
# Cross Validation Score for 13th neighbour: 0.9352724918122819
# Cross Validation Score for 14th neighbour: 0.9341246044242674
# Cross Validation Score for 15th neighbour: 0.9332999051124119
# Cross Validation Score for 16th neighbour: 0.9319122104218229
# Cross Validation Score for 17th neighbour: 0.9303411799917086
# Cross Validation Score for 18th neighbour: 0.9293194274988679
# Cross Validation Score for 19th neighbour: 0.9282553060659421
# Cross Validation Score for 20th neighbour: 0.9268474252787955
# Cross Validation Score for 21th neighbour: 0.9255146567623891
# Cross Validation Score for 22th neighbour: 0.9241156167288122
# Cross Validation Score for 23th neighbour: 0.9229169338082805
# Cross Validation Score for 24th neighbour: 0.9217081510238698
# Cross Validation Score for 25th neighbour: 0.9206497291516389
# Cross Validation Score for 26th neighbour: 0.9198487909643884
# Cross Validation Score for 27th neighbour: 0.9187518713859045
# Cross Validation Score for 28th neighbour: 0.9176013720092412
# Cross Validation Score for 29th neighbour: 0.9165776434973084
# Cross Validation Score for 30th neighbour: 0.9158334915144932
# Cross Validation Score for 31th neighbour: 0.9148537407821694
# Cross Validation Score for 32th neighbour: 0.9138089614105944
# Cross Validation Score for 33th neighbour: 0.9128823884888531
# Cross Validation Score for 34th neighbour: 0.9117187693431275
# Cross Validation Score for 35th neighbour: 0.9107104109800088
# Cross Validation Score for 36th neighbour: 0.9097238009763599
# Cross Validation Score for 37th neighbour: 0.9089046753089601
# Cross Validation Score for 38th neighbour: 0.9078802049265858
# Cross Validation Score for 39th neighbour: 0.9065760437201652
# Cross Validation Score for 40th neighbour: 0.9057037446717123
# Cross Validation Score for 41th neighbour: 0.9048427998007986
# Cross Validation Score for 42th neighbour: 0.9042443468631903
# Cross Validation Score for 43th neighbour: 0.9034159962190603
# Cross Validation Score for 44th neighbour: 0.9023443500395677
# Cross Validation Score for 45th neighbour: 0.9015677100598785
# Cross Validation Score for 46th neighbour: 0.9008913227759949
# Cross Validation Score for 47th neighbour: 0.8999992931232319
# Cross Validation Score for 48th neighbour: 0.8989957244302886
# Cross Validation Score for 49th neighbour: 0.8980666189045706
# Cross Validation Score for 50th neighbour: 0.8973901815126568
# Cross Validation Score for 51th neighbour: 0.8969868551587128
# Cross Validation Score for 52th neighbour: 0.896395523538032
# Cross Validation Score for 53th neighbour: 0.8955702907583962
# Cross Validation Score for 54th neighbour: 0.8948144300076665
# Cross Validation Score for 55th neighbour: 0.8939751270233962
# Cross Validation Score for 56th neighbour: 0.8930636450854896
# Cross Validation Score for 57th neighbour: 0.89219419109324
# Cross Validation Score for 58th neighbour: 0.891477744646531
# Cross Validation Score for 59th neighbour: 0.890707320882678
# Cross Validation Score for 60th neighbour: 0.8899987713951996
# Cross Validation Score for 61th neighbour: 0.8893764467252863
# Cross Validation Score for 62th neighbour: 0.8885990421704955
# Cross Validation Score for 63th neighbour: 0.8881549332686205
# Cross Validation Score for 64th neighbour: 0.8872656355059954
# Cross Validation Score for 65th neighbour: 0.8866062773693276
# Cross Validation Score for 66th neighbour: 0.885817266623173
# Cross Validation Score for 67th neighbour: 0.8849950088865368
# Cross Validation Score for 68th neighbour: 0.8843127371311613
# Cross Validation Score for 69th neighbour: 0.883591009809823
# Cross Validation Score for 70th neighbour: 0.8829071454127966
# Cross Validation Score for 71th neighbour: 0.8822620386420189
# Cross Validation Score for 72th neighbour: 0.8818128677188357
# Cross Validation Score for 73th neighbour: 0.8811446658499296
# Cross Validation Score for 74th neighbour: 0.8804283333187624
# Cross Validation Score for 75th neighbour: 0.8798074710703421
# Cross Validation Score for 76th neighbour: 0.879035848649327
# Cross Validation Score for 77th neighbour: 0.8784968185030927
# Cross Validation Score for 78th neighbour: 0.8778398081274889
# Cross Validation Score for 79th neighbour: 0.8772678008965
# Cross Validation Score for 80th neighbour: 0.8766085149557584
# Cross Validation Score for 81th neighbour: 0.8759663641231791
# Cross Validation Score for 82th neighbour: 0.8754199561872354
# Cross Validation Score for 83th neighbour: 0.874705759937332
# Cross Validation Score for 84th neighbour: 0.8740750329952949
# Cross Validation Score for 85th neighbour: 0.8733126203536118
# Cross Validation Score for 86th neighbour: 0.8726524435766271
# Cross Validation Score for 87th neighbour: 0.8720423771256167
# Cross Validation Score for 88th neighbour: 0.8714254383522917
# Cross Validation Score for 89th neighbour: 0.8708392037502811
# Cross Validation Score for 90th neighbour: 0.8701537608278862
# Cross Validation Score for 91th neighbour: 0.8696545131411921
# Cross Validation Score for 92th neighbour: 0.8690381099415043
# Cross Validation Score for 93th neighbour: 0.8685318608262371
# Cross Validation Score for 94th neighbour: 0.8679209480288197
# Cross Validation Score for 95th neighbour: 0.8673741356488017
# Cross Validation Score for 96th neighbour: 0.86654665544279
# Cross Validation Score for 97th neighbour: 0.8660786310269899
# Cross Validation Score for 98th neighbour: 0.8654449172752564
# Cross Validation Score for 99th neighbour: 0.864805846562031
# Cross Validation Score for 100th neighbour: 0.8643022031916798
# Cross Validation Score for 101th neighbour: 0.8636359004307039
# Cross Validation Score for 102th neighbour: 0.862900870714847
# Cross Validation Score for 103th neighbour: 0.8623718444821857
# Cross Validation Score for 104th neighbour: 0.8618656502855725
# Cross Validation Score for 105th neighbour: 0.8612681850560641
# Cross Validation Score for 106th neighbour: 0.8606163745687573
# Cross Validation Score for 107th neighbour: 0.8599732152295898
# Cross Validation Score for 108th neighbour: 0.8592740379168149
# Cross Validation Score for 109th neighbour: 0.858738348769846
# Cross Validation Score for 110th neighbour: 0.8580616765203555
# Cross Validation Score for 111th neighbour: 0.8575897621564345
# Cross Validation Score for 112th neighbour: 0.8569903813057902
# Cross Validation Score for 113th neighbour: 0.8564336825684103
# Cross Validation Score for 114th neighbour: 0.8558712656050709
# Cross Validation Score for 115th neighbour: 0.8550906485415961
# Cross Validation Score for 116th neighbour: 0.8544790545741229
# Cross Validation Score for 117th neighbour: 0.8539894640067104
# Cross Validation Score for 118th neighbour: 0.8534028967291004
# Cross Validation Score for 119th neighbour: 0.8529103018093899
# Cross Validation Score for 120th neighbour: 0.8524188078961059
# Cross Validation Score for 121th neighbour: 0.8518955603953351
# Cross Validation Score for 122th neighbour: 0.851395709520256
# Cross Validation Score for 123th neighbour: 0.8506503273289828
# Cross Validation Score for 124th neighbour: 0.8500982714939436
# Cross Validation Score for 125th neighbour: 0.8496160402770819
# Cross Validation Score for 126th neighbour: 0.8490073619788422
# Cross Validation Score for 127th neighbour: 0.8484558836748048
# Cross Validation Score for 128th neighbour: 0.8478996464843002
# Cross Validation Score for 129th neighbour: 0.847193704547389
# Cross Validation Score for 130th neighbour: 0.846578069119376
# Cross Validation Score for 131th neighbour: 0.8458895923682042
# Cross Validation Score for 132th neighbour: 0.8451908718030147
# Cross Validation Score for 133th neighbour: 0.8447094192939616
# Cross Validation Score for 134th neighbour: 0.8441654875257802
# Cross Validation Score for 135th neighbour: 0.8436012995565323
# Cross Validation Score for 136th neighbour: 0.8430014200855194
# Cross Validation Score for 137th neighbour: 0.8423422077108663
# Cross Validation Score for 138th neighbour: 0.841811788161694
# Cross Validation Score for 139th neighbour: 0.8412670416314704
# Cross Validation Score for 140th neighbour: 0.8406769329383854
# Cross Validation Score for 141th neighbour: 0.8400917776751904
# Cross Validation Score for 142th neighbour: 0.8395228315300596
# Cross Validation Score for 143th neighbour: 0.8389187437272982
# Cross Validation Score for 144th neighbour: 0.8382523158929527
# Cross Validation Score for 145th neighbour: 0.8376733514636513
# Cross Validation Score for 146th neighbour: 0.8371001680468391
# Cross Validation Score for 147th neighbour: 0.8365353337466006
# Cross Validation Score for 148th neighbour: 0.836014590727131
# Cross Validation Score for 149th neighbour: 0.8355134543419709
#
# The best score for KNN is 0.9433452550196405 for n neighbours:5

# %%
kn = KNeighborsRegressor(n_neighbors=5)
score['KNN'] = cvs(kn,x_train,y_train,cv = 10,scoring = 'r2').mean()

# %% [markdown]
# #### DECISION TREE
# <a id =6.3> </a>

# %%
#DECISION TREE
dict = {}
new_dict = {}
for i in range(3,20):
    dt = DecisionTreeRegressor(max_depth = i)
    dt.fit(x_train,y_train)
    dict[i] = {'tr':dt.score(x_train,y_train),'te':cvs(dt,x_train,y_train,cv = 10).mean()}
    new_dict[i] = cvs(dt,x_train,y_train,cv = 10,scoring = 'r2').mean()
    print("For maximum depth = ",i)
    print("Training Score:",dt.score(x_train,y_train))
    print("Cross Validation Score:",cvs(dt,x_train,y_train,cv = 10,scoring = 'r2').mean())
    
li = []
for i,j in new_dict.items():
    if len(li) == 0:
        li.extend([i,j])
    elif new_dict[i] > li[1]:
        li[0] = i
        li[1] = new_dict[i]
print("\nThe best score for Decision Tree is {} for maximum depth: {}".format(li[1],li[0]))
# Out:
# For maximum depth =  3
# Training Score: 0.7010721695899176
# Cross Validation Score: 0.6966320027811806
# For maximum depth =  4
# Training Score: 0.8339277951480908
# Cross Validation Score: 0.8299397217061599
# For maximum depth =  5
# Training Score: 0.9066115141915843
# Cross Validation Score: 0.9005125229320404
# For maximum depth =  6
# Training Score: 0.9339269171216411
# Cross Validation Score: 0.924638420952142
# For maximum depth =  7
# Training Score: 0.9535170104005755
# Cross Validation Score: 0.9431017641985134
# For maximum depth =  8
# Training Score: 0.9689163364755079
# Cross Validation Score: 0.954433819148465
# For maximum depth =  9
# Training Score: 0.9806295671284723
# Cross Validation Score: 0.9619256148489266
# For maximum depth =  10
# Training Score: 0.9887077298815432
# Cross Validation Score: 0.9651293729337818
# For maximum depth =  11
# Training Score: 0.9940545463153821
# Cross Validation Score: 0.966872742927503
# For maximum depth =  12
# Training Score: 0.9970034527642804
# Cross Validation Score: 0.9669788130670328
# For maximum depth =  13
# Training Score: 0.9985893449925582
# Cross Validation Score: 0.9669689144975049
# For maximum depth =  14
# Training Score: 0.999366970381884
# Cross Validation Score: 0.9664227138820183
# For maximum depth =  15
# Training Score: 0.9997148352725928
# Cross Validation Score: 0.9664502720645158
# For maximum depth =  16
# Training Score: 0.9998695112925274
# Cross Validation Score: 0.966513600016982
# For maximum depth =  17
# Training Score: 0.9999628551990554
# Cross Validation Score: 0.9670952012830446
# For maximum depth =  18
# Training Score: 0.9999900662506852
# Cross Validation Score: 0.9669307396353523
# For maximum depth =  19
# Training Score: 0.9999963212798599
# Cross Validation Score: 0.9669814544671181
#
# The best score for Decision Tree is 0.9670331711682796 for maximum depth: 11

# %%
dtree = pd.DataFrame(dict).T.reset_index()

# %%
plt.figure(figsize = (12,8))
sns.barplot(data = dtree,y = "tr",x = "index",color = 'black')
sns.barplot(data = dtree,y = "te",x = "index",color = 'green')
plt.ylabel('Training and Cross Validation Scores')
# Out:
# Text(0, 0.5, 'Training and Cross Validation Scores')

# %%
dt = DecisionTreeRegressor(max_depth = 11)
dt.fit(x_train,y_train)
score['Decision Tree'] = cvs(dt,x_train,y_train,cv = 10,scoring = 'r2').mean()

# %% [markdown]
# #### RANDOM FOREST
# <a id =6.4> </a>

# %%
#RANDOM FOREST
dict = {}
new_dict = {}
for i in range(3,20):
    rf = RandomForestRegressor(max_depth = i,)
    rf.fit(x_train,y_train)
    dict[i] = {'tr':rf.score(x_train,y_train),'te':cvs(rf,x_test,y_test,cv =10 ).mean()}
    new_dict[i] = cvs(dt,x_train,y_train,cv = 10,scoring = 'r2').mean()
    print("For maximum depth = ",i)
    print("Training Score:",rf.score(x_train,y_train))
    print("Validation Score:",cvs(rf,x_test,y_test,cv =10 ).mean())
    
li = []
for i,j in new_dict.items():
    if len(li) == 0:
        li.extend([i,j])
    elif new_dict[i] > li[1]:
        li[0] = i
        li[1] = new_dict[i]
print("\nThe best score for Decision Tree is {} for maximum depth: {}".format(li[1],li[0]))
# Out:
# For maximum depth =  3
# Training Score: 0.7046523631913876
# Validation Score: 0.7571260911078523
# For maximum depth =  4
# Training Score: 0.840412573014694
# Validation Score: 0.8672152122658222
# For maximum depth =  5
# Training Score: 0.9156240210816992
# Validation Score: 0.923752766605644
# For maximum depth =  6
# Training Score: 0.946292502337633
# Validation Score: 0.9454778328749385
# For maximum depth =  7
# Training Score: 0.9670502650855206
# Validation Score: 0.9598152894467515
# For maximum depth =  8
# Training Score: 0.980444713579478
# Validation Score: 0.9671628071791588
# For maximum depth =  9
# Training Score: 0.9884207185387688
# Validation Score: 0.9710758393702618
# For maximum depth =  10
# Training Score: 0.9931823246219068
# Validation Score: 0.9731672049582766
# For maximum depth =  11
# Training Score: 0.9958153811999726
# Validation Score: 0.973923365562575
# For maximum depth =  12
# Training Score: 0.997037860484251
# Validation Score: 0.9741953727302246
# For maximum depth =  13
# Training Score: 0.9976519647801333
# Validation Score: 0.9741275165710601
# For maximum depth =  14
# Training Score: 0.9978825569832107
# Validation Score: 0.9742325466114279
# For maximum depth =  15
# Training Score: 0.9980183892937055
# Validation Score: 0.9740972497672352
# For maximum depth =  16
# Training Score: 0.9980128060232324
# Validation Score: 0.9745745117540643
# For maximum depth =  17
# Training Score: 0.9980710717744337
# Validation Score: 0.9741466301931965
# For maximum depth =  18
# Training Score: 0.9980320921972998
# Validation Score: 0.9743071342480312
# For maximum depth =  19
# Training Score: 0.9980532573340384
# Validation Score: 0.9741783376408767
#
# The best score for Decision Tree is 0.9673973267019568 for maximum depth: 16

# %%
rforest = pd.DataFrame(dict).T.reset_index()

# %%
plt.figure(figsize = (12,8))
sns.barplot(data = rforest,y = "tr",x = "index",color = 'r')
sns.barplot(data = rforest,y = "te",x = "index",color = 'b')
plt.ylabel('Training and Cross Validation Scores')
# Out:
# Text(0, 0.5, 'Training and Cross Validation Scores')

# %%
dt = RandomForestRegressor(max_depth = 13)
dt.fit(x_train,y_train)
score['Random Forest'] = cvs(dt,x_train,y_train,cv = 10,scoring = 'r2').mean()
score
# Out:
# {'Linear Regression': 0.9120807004250727,
#  'KNN': 0.9433452550196405,
#  'Decision Tree': 0.9668976966503176,
#  'Random Forest': 0.985252302683039}

# %% [markdown]
# #### XGBOOST
# <a id =6.5> </a>

# %%
#xgboost
xg = XGBRegressor(objective ='reg:squarederror',n_estimators = 200, seed = 123,learning_rate = 0.099)
xg.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.099, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=200, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=123,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=123,
#              subsample=1, tree_method='exact', validate_parameters=1,
#              verbosity=None)

# %%
# print("Training Score:",xg.score(x_test,y_test))
print("Validation Score:",cvs(xg,x_train,y_train,cv=10).mean())
print("Validation Score testing:",cvs(xg,x_test,y_test,cv=10).mean())
# Out:
# Validation Score: 0.9937602782325399
# Validation Score testing: 0.9900025707809222

# %%
dict ={}
lis = [0.0001,0.001,0.11,2]
for i in np.arange(0.01,0.4,0.01):
    xg = XGBRegressor(n_estimators = 200,learning_rate = i)
    xg.fit(x_train, y_train)
    print("Learning Rate:{}".format(i))
#     print("Training Score:",xg.score(x_test,y_test))
    dict[i] = cvs(xg,x_train,y_train,cv=10).mean()
    print("Training Validation Score:",cvs(xg,x_train,y_train,cv=10,scoring = 'r2').mean())
    print("Testing Validation Score:",cvs(xg,x_test,y_test,cv=10,scoring = 'r2').mean())
#finding the highest score 
li = []
for i,j in dict.items():
    if len(li) == 0:
        li.extend([i,j])
    elif dict[i] > li[1]:
        li[0] = i
        li[1] = dict[i]
print("\nThe best score for XGBoost is {} for learning rate:{}".format(li[1],li[0]))
# Out:
# Learning Rate:0.01
# Training Validation Score: 0.7870009646613582
# Testing Validation Score: 0.7718667148525022
# Learning Rate:0.02
# Training Validation Score: 0.9818203275966646
# Testing Validation Score: 0.9765479978946985
# Learning Rate:0.03
# Training Validation Score: 0.9906091066458245
# Testing Validation Score: 0.9864866254901468
# Learning Rate:0.04
# Training Validation Score: 0.992483880407294
# Testing Validation Score: 0.9886355373850304
# Learning Rate:0.05
# Training Validation Score: 0.9932256339387688
# Testing Validation Score: 0.989556302326063
# Learning Rate:0.060000000000000005
# Training Validation Score: 0.9934858789343453
# Testing Validation Score: 0.9898553975409049
# Learning Rate:0.06999999999999999
# Training Validation Score: 0.9935638316891506
# Testing Validation Score: 0.9898079310936607
# Learning Rate:0.08
# Training Validation Score: 0.9936181871059319
# Testing Validation Score: 0.9901456985279964
# Learning Rate:0.09
# Training Validation Score: 0.993621453335237
# Testing Validation Score: 0.989973782352458
# Learning Rate:0.09999999999999999
# Training Validation Score: 0.9937583502868488
# Testing Validation Score: 0.9898254291407053
# Learning Rate:0.11
# Training Validation Score: 0.9936054093588623
# Testing Validation Score: 0.9896926654959518
# Learning Rate:0.12
# Training Validation Score: 0.9937046136923188
# Testing Validation Score: 0.9896116559422659
# Learning Rate:0.13
# Training Validation Score: 0.9934808905545955
# Testing Validation Score: 0.9896244509345438
# Learning Rate:0.14
# Training Validation Score: 0.9934939218817771
# Testing Validation Score: 0.9895892246902992
# Learning Rate:0.15000000000000002
# Training Validation Score: 0.9934915394085945
# Testing Validation Score: 0.9891958256399033
# Learning Rate:0.16
# Training Validation Score: 0.9933042916547326
# Testing Validation Score: 0.9894763791247115
# Learning Rate:0.17
# Training Validation Score: 0.9931684622119171
# Testing Validation Score: 0.9893014110770324
# Learning Rate:0.18000000000000002
# Training Validation Score: 0.9930719386038287
# Testing Validation Score: 0.9890561824646644
# Learning Rate:0.19
# Training Validation Score: 0.9932059468689125
# Testing Validation Score: 0.9890041363917526
# Learning Rate:0.2
# Training Validation Score: 0.9928706985023259
# Testing Validation Score: 0.98887408063531
# Learning Rate:0.21000000000000002
# Training Validation Score: 0.9928448933929964
# Testing Validation Score: 0.9886938158975234
# Learning Rate:0.22
# Training Validation Score: 0.9927767336780796
# Testing Validation Score: 0.9876697222789836
# Learning Rate:0.23
# Training Validation Score: 0.9925359770880482
# Testing Validation Score: 0.9879755092018554
# Learning Rate:0.24000000000000002
# Training Validation Score: 0.9924199700581593
# Testing Validation Score: 0.9877428432735857
# Learning Rate:0.25
# Training Validation Score: 0.9924194084782376
# Testing Validation Score: 0.9878851070774027
# Learning Rate:0.26
# Training Validation Score: 0.992299245359573
# Testing Validation Score: 0.9875717990380943
# Learning Rate:0.27
# Training Validation Score: 0.9919992357628443
# Testing Validation Score: 0.9873086954852107
# Learning Rate:0.28
# Training Validation Score: 0.9918310540219306
# Testing Validation Score: 0.9868588363388027
# Learning Rate:0.29000000000000004
# Training Validation Score: 0.9918725149568672
# Testing Validation Score: 0.9869259827074197
# Learning Rate:0.3
# Training Validation Score: 0.9916023352666109
# Testing Validation Score: 0.9869295837433075
# Learning Rate:0.31
# Training Validation Score: 0.9911748143938233
# Testing Validation Score: 0.9859291356664002
# Learning Rate:0.32
# Training Validation Score: 0.9910035081041932
# Testing Validation Score: 0.9851343037218901
# Learning Rate:0.33
# Training Validation Score: 0.9910172517281032
# Testing Validation Score: 0.984957422720057
# Learning Rate:0.34
# Training Validation Score: 0.9907784060393106
# Testing Validation Score: 0.985204089717997
# Learning Rate:0.35000000000000003
# Training Validation Score: 0.9909412300806739
# Testing Validation Score: 0.9851096962247526
# Learning Rate:0.36000000000000004
# Training Validation Score: 0.990496643160558
# Testing Validation Score: 0.9838281574252855
# Learning Rate:0.37
# Training Validation Score: 0.9901344917684922
# Testing Validation Score: 0.9835583701999546
# Learning Rate:0.38
# Training Validation Score: 0.9902462468713086
# Testing Validation Score: 0.983769992650014
# Learning Rate:0.39
# Training Validation Score: 0.990146322837971
# Testing Validation Score: 0.9830189776003759
#
# The best score for XGBoost is 0.9937583502868488 for learning rate:0.09999999999999999

# %%
xg = XGBRegressor(n_estimators = 200,learning_rate = 0.09999999999999999)
xg.fit(x_train, y_train)
# print("Training Score:",xg.score(x_test,y_test))
score['XGBoost'] = cvs(xg,x_train,y_train,cv=10,scoring = 'r2').mean()

# %%
scores = pd.Series(score)
print("These are all the scores of the Regressor Models we used: ")
print(scores);
# Out:
# These are all the scores of the Regressor Models we used:
# Linear Regression    0.912081
# KNN                  0.943345
# Decision Tree        0.966898
# Random Forest        0.985252
# XGBoost              0.993758
# dtype: float64

# %% [markdown]
# #### Out of all these Regressor models XGBoost performs the best.

# %% [markdown]
# ### FINAL MODEL

# %%
model_xg = XGBRegressor(n_estimators = 200,learning_rate = 0.09999999999999999)
xg.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.09999999999999999,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=200, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
#  <a id =7> </a>
# ## FEATURE IMPORTANCES

# %%
coef = pd.Series({i:abs(j) for i,j in zip(x_train.columns,xg.feature_importances_)})
# coef.drop(['buildtype0','buildtype1'],inplace = True)

# %%
coef.sort_values(ascending = False).plot(kind = "bar")
plt.title('Importances of Features/Factors');
plt.show()

# %%
feature_coef = coef.drop(['buildtype0','buildtype1'])
feature_coef.sort_values(ascending = False).plot(kind = "bar")
plt.title('Importances of Features/Factors(excluding buildtype)');
plt.show()

# %% [markdown]
# It is quite evident from the graph that `BUILDTYPE, AREA, N_ROOM` are the important factors that decide the sale of Houses, But it cannot just be said based upon feature importances, also nothing can be said about build type as it is a `ONE HOT ENCODED`col

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# copied the dataset before encoding
df1.head()
# Out:
#    area  int_sqft  n_bedroom  n_bathroom  n_room  park_facil     buildtype  \
# 0     0      1004          1           1       1           1  1.386984e+07
# 1     5      1986          2           1       3           0  1.386984e+07
# 2     1       909          1           1       1           1  1.386984e+07
# 3     3      1855          3           2       3           0  9.807998e+06
# 4     0      1226          1           1       1           1  9.807998e+06
#
#    utility_avail  street  mzzone  qs_overall  house_age(in years)  \
# 0              2       1       0       4.330                43.89
# 1              2       2       4       3.765                10.99
# 2              0       2       5       3.090                19.58
# 3              1       1       2       4.010                21.98
# 4              2       2       1       3.290                29.57
#
#    sales_price     grp_house_age
# 0      7600000  (40.208, 45.392]
# 1     21717770   (9.104, 14.288]
# 2     13159200  (19.472, 24.656]
# 3      9630290  (19.472, 24.656]
# 4      7406250   (24.656, 29.84]

# %%
df_before_encoding = data.copy(deep = False)

# %%
df1= df_before_encoding.copy(deep = False)

# %%
df1.buildtype.unique()
# Out:
# array(['Commercial', 'Others', 'House'], dtype=object)

# %%
#here we are label encoding buildtype column here for feature importance
df1.area = df1.area.map({'Karapakkam':0,'Adyar':1,'Chrompet':2,'Velachery':3,\
'KKNagar':4,'AnnaNagar':5,'TNagar':6
})
df1.park_facil = df1.park_facil.map({'Yes':1,'No':0})
df1.utility_avail = df1.utility_avail.map({'ELO':0,'NoSewr':1,"AllPub":2})
df1.street = df1.street.map({'NoAccess':0,'Paved':1,'Gravel':2})
df1.mzzone = df1.mzzone.map({'A':0,'C':1,'I':2,'RH':4,'RL':5,'RM':6})
df1.n_room = df1.n_room.map({2:0,3:1,4:2,5:3,6:3})

# %%
# mean encoding buildtype

Mean_encoded_subject = df1.groupby(['buildtype'])['sales_price'].mean().to_dict()
df1['buildtype'] =  df1['buildtype'].map(Mean_encoded_subject)

# %%
# delete qs_bedroom,bathroom,room,distfrommainroad
df1.drop(['sale_cond','dist_mainroad','qs_rooms','qs_bathroom','qs_bedroom'],axis =1 ,inplace = True)
df1.head()
# Out:
#    area  int_sqft  n_bedroom  n_bathroom  n_room  park_facil     buildtype  \
# 0     0      1004          1           1       1           1  1.386984e+07
# 1     5      1986          2           1       3           0  1.386984e+07
# 2     1       909          1           1       1           1  1.386984e+07
# 3     3      1855          3           2       3           0  9.807998e+06
# 4     0      1226          1           1       1           1  9.807998e+06
#
#    utility_avail  street  mzzone  qs_overall  house_age(in years)  \
# 0              2       1       0       4.330                43.89
# 1              2       2       4       3.765                10.99
# 2              0       2       5       3.090                19.58
# 3              1       1       2       4.010                21.98
# 4              2       2       1       3.290                29.57
#
#    sales_price     grp_house_age
# 0      7600000  (40.208, 45.392]
# 1     21717770   (9.104, 14.288]
# 2     13159200  (19.472, 24.656]
# 3      9630290  (19.472, 24.656]
# 4      7406250   (24.656, 29.84]

# %%
y_feature_imp = df1['sales_price']
X_feature_imp = df1.drop(['sales_price','grp_house_age'],axis =1)

# %%
x_feat_train,x_feat_test,y_feat_train,y_feat_test = train_test_split(X_feature_imp,y_feature_imp,
                                                                     test_size = 0.25,
                                                                     random_state = 20)

# %%
# x_feat_train= pd.DataFrame(sc.fit_transform(x_feat_train),columns = x_feat_train.columns)

# %%
x_train.head()
# Out:
#        area  int_sqft  n_bedroom  n_bathroom    n_room  park_facil  \
# 0 -0.844066 -0.513836  -0.791773   -0.516597 -0.691736    0.995321
# 1 -0.844066 -0.605813  -0.791773   -0.516597 -0.691736    0.995321
# 2  1.308650  0.933694   0.456288   -0.516597  1.407691   -1.004701
# 3  1.308650  0.668715  -0.791773   -0.516597  0.357978   -1.004701
# 4  1.846829  1.244661   0.456288   -0.516597  1.407691    0.995321
#
#    utility_avail    street    mzzone  qs_overall  house_age(in years)  \
# 0       1.384644 -0.088278  0.484531    0.219354             1.190713
# 1      -0.063284  1.173413 -2.207250    0.047875            -0.024621
# 2      -0.063284 -0.088278 -0.053826    0.810004             1.278275
# 3      -1.511212 -0.088278 -0.053826   -0.256976            -0.607560
# 4       1.384644 -1.349970  1.022887    1.067222            -0.834574
#
#    buildtype0  buildtype1
# 0    1.368888   -0.707107
# 1   -0.730520    1.414214
# 2   -0.730520    1.414214
# 3   -0.730520   -0.707107
# 4    1.368888   -0.707107

# %%
x_feat_train.head()
# Out:
#       area  int_sqft  n_bedroom  n_bathroom  n_room  park_facil     buildtype  \
# 1097     1      1152          1           1       1           1  9.098847e+06
# 1740     1      1110          1           1       1           1  9.807998e+06
# 3469     5      1813          2           1       3           0  9.807998e+06
# 4198     5      1692          1           1       2           0  1.386984e+07
# 4038     6      1955          2           1       3           1  9.098847e+06
#
#       utility_avail  street  mzzone  qs_overall  house_age(in years)
# 1097              2       1       5       3.620                38.97
# 1740              1       2       0       3.530                23.98
# 3469              1       1       4       3.930                40.05
# 4198              0       1       4       3.370                16.79
# 4038              2       0       6       4.065                13.99

# %%
dict ={}
lis = [0.0001,0.001,0.11,2]
for i in np.arange(0.01,0.4,0.01):
    xg = XGBRegressor(n_estimators = 200,learning_rate = i)
    xg.fit(x_feat_train, y_feat_train)
    print("Learning Rate:{}".format(i))
#     print("Training Score:",xg.score(x_test,y_test))
    dict[i] = cvs(xg,x_feat_train,y_feat_train,cv=10).mean()
    print("Training Validation Score:",cvs(xg,x_feat_train,y_feat_train,cv=10,scoring = 'r2').mean())
    print("Testing Validation Score:",cvs(xg,x_feat_train,y_feat_train,cv=10,scoring = 'r2').mean())
#finding the highest score 
li = []
for i,j in dict.items():
    if len(li) == 0:
        li.extend([i,j])
    elif dict[i] > li[1]:
        li[0] = i
        li[1] = dict[i]
# print("\nThe best score for XGBoost is {} for learning rate:{}".format(li[1],li[0]))
# Out:
# Learning Rate:0.01
# Training Validation Score: 0.792594149132992
# Testing Validation Score: 0.792594149132992
# Learning Rate:0.02
# Training Validation Score: 0.9837973114397196
# Testing Validation Score: 0.9837973114397196
# Learning Rate:0.03
# Training Validation Score: 0.9915864089509483
# Testing Validation Score: 0.9915864089509483
# Learning Rate:0.04
# Training Validation Score: 0.9930785420059955
# Testing Validation Score: 0.9930785420059955
# Learning Rate:0.05
# Training Validation Score: 0.993694126607328
# Testing Validation Score: 0.993694126607328
# Learning Rate:0.060000000000000005
# Training Validation Score: 0.993925029668295
# Testing Validation Score: 0.993925029668295
# Learning Rate:0.06999999999999999
# Training Validation Score: 0.994025651540178
# Testing Validation Score: 0.994025651540178
# Learning Rate:0.08
# Training Validation Score: 0.9939668226811517
# Testing Validation Score: 0.9939668226811517
# Learning Rate:0.09
# Training Validation Score: 0.9939866852517605
# Testing Validation Score: 0.9939866852517605
# Learning Rate:0.09999999999999999
# Training Validation Score: 0.9940061833697358
# Testing Validation Score: 0.9940061833697358
# Learning Rate:0.11
# Training Validation Score: 0.9940434281241124
# Testing Validation Score: 0.9940434281241124
# Learning Rate:0.12
# Training Validation Score: 0.9940345085810547
# Testing Validation Score: 0.9940345085810547
# Learning Rate:0.13
# Training Validation Score: 0.9938403564338563
# Testing Validation Score: 0.9938403564338563
# Learning Rate:0.14
# Training Validation Score: 0.993802638844602
# Testing Validation Score: 0.993802638844602
# Learning Rate:0.15000000000000002
# Training Validation Score: 0.9938800782784336
# Testing Validation Score: 0.9938800782784336
# Learning Rate:0.16
# Training Validation Score: 0.9936885094525214
# Testing Validation Score: 0.9936885094525214
# Learning Rate:0.17
# Training Validation Score: 0.9936601171358216
# Testing Validation Score: 0.9936601171358216
# Learning Rate:0.18000000000000002
# Training Validation Score: 0.9935291746708603
# Testing Validation Score: 0.9935291746708603
# Learning Rate:0.19
# Training Validation Score: 0.9934424090926338
# Testing Validation Score: 0.9934424090926338
# Learning Rate:0.2
# Training Validation Score: 0.9933472611942872
# Testing Validation Score: 0.9933472611942872
# Learning Rate:0.21000000000000002
# Training Validation Score: 0.9931505450556429
# Testing Validation Score: 0.9931505450556429
# Learning Rate:0.22
# Training Validation Score: 0.9931580486669687
# Testing Validation Score: 0.9931580486669687
# Learning Rate:0.23
# Training Validation Score: 0.99286663298502
# Testing Validation Score: 0.99286663298502
# Learning Rate:0.24000000000000002
# Training Validation Score: 0.9929612605371088
# Testing Validation Score: 0.9929612605371088
# Learning Rate:0.25
# Training Validation Score: 0.9926057548074623
# Testing Validation Score: 0.9926057548074623
# Learning Rate:0.26
# Training Validation Score: 0.9927764911510625
# Testing Validation Score: 0.9927764911510625
# Learning Rate:0.27
# Training Validation Score: 0.9925736284550217
# Testing Validation Score: 0.9925736284550217
# Learning Rate:0.28
# Training Validation Score: 0.992368448439587
# Testing Validation Score: 0.992368448439587
# Learning Rate:0.29000000000000004
# Training Validation Score: 0.9921424388134044
# Testing Validation Score: 0.9921424388134044
# Learning Rate:0.3
# Training Validation Score: 0.9919923399060501
# Testing Validation Score: 0.9919923399060501
# Learning Rate:0.31
# Training Validation Score: 0.9921497155683298
# Testing Validation Score: 0.9921497155683298
# Learning Rate:0.32
# Training Validation Score: 0.99166851462014
# Testing Validation Score: 0.99166851462014
# Learning Rate:0.33
# Training Validation Score: 0.9916240038387789
# Testing Validation Score: 0.9916240038387789
# Learning Rate:0.34
# Training Validation Score: 0.9915519028840484
# Testing Validation Score: 0.9915519028840484
# Learning Rate:0.35000000000000003
# Training Validation Score: 0.9915137500887139
# Testing Validation Score: 0.9915137500887139
# Learning Rate:0.36000000000000004
# Training Validation Score: 0.9911712529691978
# Testing Validation Score: 0.9911712529691978
# Learning Rate:0.37
# Training Validation Score: 0.9909628113403789
# Testing Validation Score: 0.9909628113403789
# Learning Rate:0.38
# Training Validation Score: 0.9908470257623622
# Testing Validation Score: 0.9908470257623622
# Learning Rate:0.39
# Training Validation Score: 0.9907668832914606
# Testing Validation Score: 0.9907668832914606

# %%
print("\nThe best score for XGBoost is {} for learning rate:{}".format(li[1],li[0]))
# Out:
# The best score for XGBoost is 0.9940434281241124 for learning rate:0.11

# %%
xg = XGBRegressor(n_estimators = 200,learning_rate = 0.11)
xg.fit(x_feat_train, y_feat_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.11, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=200, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
shap_values = shap.TreeExplainer(xg).shap_values(x_feat_train)

# %%
shap.summary_plot(shap_values, x_feat_train, plot_type="bar")

# %% [markdown]
#  <a id =8> </a>
#
# ## CONCLUSION

# %% [markdown]
# From the above project we found that:
# 1. **XGBoost** with `n_estimators = 200 and learning_rate = 0.0999` gives the best **`score(99.38%)`** among all other Regression Models <br>
# 2. **`buildtype, area, intsqft & mzzone`** are the features/factors that mostly affect the sales of houses.
# <br><br>
#
# ***
# <span>
# And below here are a few inferences we derived:<br><br>
# 1. Chrompet has most number of house while TNagar has the least.<br>
# 2. Houses with 1 bedroom is most preferred following by 2 bedrooms.<br>
# 3. Houses with 3 to 4 rooms is most preffered.<br>
# 4. Almost half of the houses doesn't have parking facility.<br>
# 5. 52% of houses does have no Sewer facility.<br>
# 6. 28% of houses doesn't have proper road access.<br>
# 7. Houses for Industrial,Agricultural and Commercial Purposes are very less

# %% [markdown]
# [go to top](#0)
